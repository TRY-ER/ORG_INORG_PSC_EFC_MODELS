# %%
import pandas as pd
import numpy as np
from imblearn.over_sampling import SMOTE
import matplotlib.pyplot as plt

# %%
main_df = pd.read_csv("main_df.csv")

# %%
main_df.columns
# Out:
# Index(['Paper #', 'Device #', 'DOI', 'Manufacturer',
#        'Manuscripted submitted year', 'Country', 'Efficiency (%)', 'Voc (V)',
#        'Voc per cell (V)', 'Isc (mA)', 'Jsc (mA/cm^2)', 'FF (%)', 'Pmax (mW)',
#        'Vmax (V)', 'Imax (mA)', 'Apeture area (cm^2)', 'Device size type',
#        'Sweep direction', 'Sweep rate (mV/s)', 'Certified year',
#        'Transparent conductive oxide type', 'Electron transport layer type',
#        'Perovskite composition', 'Perovskite chemistry type', 'extra',
#        'extra%', 'MA', 'FA', 'Pb', 'I', 'Br', 'Passive_layer',
#        'Perovksite depostion method', 'Hole transport layer type',
#        'Conductive electrode layer', 'Device structure', 'exposed_time',
#        'retained_per', 'stability'],
#       dtype='object')

# %%
minor_cols = ['Paper #', 'Device #', 'DOI', 'Manufacturer',
       'Manuscripted submitted year', 'Country','Sweep rate (mV/s)','Certified year', 'Passive_layer','extra','extra%','Perovskite composition', 'Perovskite chemistry type']

# %%
use_df = main_df.drop(minor_cols,axis=1)

# %%
use_df.columns
# Out:
# Index(['Efficiency (%)', 'Voc (V)', 'Voc per cell (V)', 'Isc (mA)',
#        'Jsc (mA/cm^2)', 'FF (%)', 'Pmax (mW)', 'Vmax (V)', 'Imax (mA)',
#        'Apeture area (cm^2)', 'Device size type', 'Sweep direction',
#        'Transparent conductive oxide type', 'Electron transport layer type',
#        'MA', 'FA', 'Pb', 'I', 'Br', 'Perovksite depostion method',
#        'Hole transport layer type', 'Conductive electrode layer',
#        'Device structure', 'exposed_time', 'retained_per', 'stability'],
#       dtype='object')

# %%
def change_dtype(df):
  for col in df.columns:
    try:
      float(df[col].values[0])
      df[col] = df[col].astype(float)
    except:
      try:
        int(df[col].values[0])
        df[col] = df[col].astype(int)
      except:
        try:
          str(df[col].values[0])
          df[col] = df[col].astype(str)
        except:
          df[col] = df[col].astype(object)
  return df

# %%
def make_classes(mod_df):
    condition = [mod_df['Efficiency (%)'] <= 15.0,
          (mod_df['Efficiency (%)'] > 15.0) & (mod_df['Efficiency (%)'] <= 20.0),
          mod_df['Efficiency (%)'] > 20.0]
    values = ['low_efficient','moderate_efficient','high_efficient']
    mod_df['cat_efc'] = np.select(condition,values)
    condition_sta = [mod_df['stability'] <= 100.0,
          (mod_df['stability'] > 100.0) & (mod_df['stability'] <= 300.0),
          mod_df['stability'] > 300]
    values_sta = ['unstable','low_stabiity','stable']
    mod_df['cat_sta'] = np.select(condition_sta,values_sta)
    return mod_df

# %%
sta_vals = use_df.stability.values

# %%
sta_main = []
for val in sta_vals:
    try:
        k = float(val)
        sta_main.append(k)
    except:
        pass

# %%
temp_df = pd.DataFrame(sta_main)

# %% [markdown]
# temp_df.mode()

# %%
temp_df.median()
# Out:
# 0    64.8
# dtype: float64

# %%
use_df["stability"].replace("unknown",64.8,inplace=True)

# %%
use_df.head()
# Out:
#    Efficiency (%)  Voc (V)  Voc per cell (V)  Isc (mA)  Jsc (mA/cm^2)  FF (%)  \
# 0           14.14   1.0071            1.0071     4.460      21.339713    65.7
# 1           16.15   1.1085            1.1085     1.840      19.616205    74.2
# 2           12.84   0.8579            0.8579     1.650      22.758621    65.8
# 3           20.11   1.0590            1.0590     2.354      24.649215    77.0
# 4           15.00   1.0900            1.0900    20.960      20.609636    66.8
#
#    Pmax (mW)  Vmax (V)  Imax (mA)  Apeture area (cm^2)  ... Pb     I    Br  \
# 0       2.96    0.7763      3.810               0.2090  ...  1  3.00  0.00
# 1       1.51    0.9052      1.670               0.0938  ...  1  2.58  0.42
# 2       0.93    0.6540      1.420               0.0725  ...  1  3.00  0.00
# 3       1.92    0.8940      2.148               0.0955  ...  1  2.85  0.15
# 4      15.26    0.8790     17.350               1.0170  ...  1  3.00  0.00
#
#   Perovksite depostion method  Hole transport layer type  \
# 0                spin coating               Spiro-OMeTAD
# 1                spin coating                       PTAA
# 2             screen printing                     No HTL
# 3                spin coating                       PTAA
# 4                spin coating                    NiMgLiO
#
#    Conductive electrode layer  Device structure  exposed_time  retained_per  \
# 0                          Au        Mesoscopic           500            80
# 1                          Au        Mesoscopic       unknown       unknown
# 2       carbon black/graphite        Mesoscopic          1008           100
# 3                          Au        Mesoscopic        unkown       unknown
# 4                          Ag   Inverted planar          1000            97
#
#   stability
# 0        40
# 1      64.8
# 2     100.8
# 3      64.8
# 4        97
#
# [5 rows x 26 columns]

# %%
sta_vals = use_df.exposed_time.values
exp_time_main = []
for val in sta_vals:
    try:
        k = float(val)
        exp_time_main.append(k)
    except:
        pass
temp_df = pd.DataFrame(exp_time_main)
print(temp_df.median())
use_df["exposed_time"].replace("unknown",720.0,inplace=True)
use_df["exposed_time"].replace("unkown",720.0,inplace=True)
# Out:
# 0    720.0
# dtype: float64

# %%
use_df.head()
# Out:
#    Efficiency (%)  Voc (V)  Voc per cell (V)  Isc (mA)  Jsc (mA/cm^2)  FF (%)  \
# 0           14.14   1.0071            1.0071     4.460      21.339713    65.7
# 1           16.15   1.1085            1.1085     1.840      19.616205    74.2
# 2           12.84   0.8579            0.8579     1.650      22.758621    65.8
# 3           20.11   1.0590            1.0590     2.354      24.649215    77.0
# 4           15.00   1.0900            1.0900    20.960      20.609636    66.8
#
#    Pmax (mW)  Vmax (V)  Imax (mA)  Apeture area (cm^2)  ... Pb     I    Br  \
# 0       2.96    0.7763      3.810               0.2090  ...  1  3.00  0.00
# 1       1.51    0.9052      1.670               0.0938  ...  1  2.58  0.42
# 2       0.93    0.6540      1.420               0.0725  ...  1  3.00  0.00
# 3       1.92    0.8940      2.148               0.0955  ...  1  2.85  0.15
# 4      15.26    0.8790     17.350               1.0170  ...  1  3.00  0.00
#
#   Perovksite depostion method  Hole transport layer type  \
# 0                spin coating               Spiro-OMeTAD
# 1                spin coating                       PTAA
# 2             screen printing                     No HTL
# 3                spin coating                       PTAA
# 4                spin coating                    NiMgLiO
#
#    Conductive electrode layer  Device structure  exposed_time  retained_per  \
# 0                          Au        Mesoscopic           500            80
# 1                          Au        Mesoscopic           720       unknown
# 2       carbon black/graphite        Mesoscopic          1008           100
# 3                          Au        Mesoscopic           720       unknown
# 4                          Ag   Inverted planar          1000            97
#
#   stability
# 0        40
# 1      64.8
# 2     100.8
# 3      64.8
# 4        97
#
# [5 rows x 26 columns]

# %%
sta_vals = use_df.retained_per.values
retain_main = []
for val in sta_vals:
    try:
        k = float(val)
        retain_main.append(k)
    except:
        pass
temp_df = pd.DataFrame(retain_main)
print(temp_df.median())
# Out:
# 0    91.0
# dtype: float64

# %%
use_df["retained_per"].replace("unknown",720.0,inplace=True)
use_df["retained_per"].replace("unkown",720.0,inplace=True)

# %%
use_df.head()
# Out:
#    Efficiency (%)  Voc (V)  Voc per cell (V)  Isc (mA)  Jsc (mA/cm^2)  FF (%)  \
# 0           14.14   1.0071            1.0071     4.460      21.339713    65.7
# 1           16.15   1.1085            1.1085     1.840      19.616205    74.2
# 2           12.84   0.8579            0.8579     1.650      22.758621    65.8
# 3           20.11   1.0590            1.0590     2.354      24.649215    77.0
# 4           15.00   1.0900            1.0900    20.960      20.609636    66.8
#
#    Pmax (mW)  Vmax (V)  Imax (mA)  Apeture area (cm^2)  ... Pb     I    Br  \
# 0       2.96    0.7763      3.810               0.2090  ...  1  3.00  0.00
# 1       1.51    0.9052      1.670               0.0938  ...  1  2.58  0.42
# 2       0.93    0.6540      1.420               0.0725  ...  1  3.00  0.00
# 3       1.92    0.8940      2.148               0.0955  ...  1  2.85  0.15
# 4      15.26    0.8790     17.350               1.0170  ...  1  3.00  0.00
#
#   Perovksite depostion method  Hole transport layer type  \
# 0                spin coating               Spiro-OMeTAD
# 1                spin coating                       PTAA
# 2             screen printing                     No HTL
# 3                spin coating                       PTAA
# 4                spin coating                    NiMgLiO
#
#    Conductive electrode layer  Device structure  exposed_time  retained_per  \
# 0                          Au        Mesoscopic           500            80
# 1                          Au        Mesoscopic           720           720
# 2       carbon black/graphite        Mesoscopic          1008           100
# 3                          Au        Mesoscopic           720           720
# 4                          Ag   Inverted planar          1000            97
#
#   stability
# 0        40
# 1      64.8
# 2     100.8
# 3      64.8
# 4        97
#
# [5 rows x 26 columns]

# %%
use_df=change_dtype(use_df)
use_df=make_classes(use_df)

# %%
use_df.columns
# Out:
# Index(['Efficiency (%)', 'Voc (V)', 'Voc per cell (V)', 'Isc (mA)',
#        'Jsc (mA/cm^2)', 'FF (%)', 'Pmax (mW)', 'Vmax (V)', 'Imax (mA)',
#        'Apeture area (cm^2)', 'Device size type', 'Sweep direction',
#        'Transparent conductive oxide type', 'Electron transport layer type',
#        'MA', 'FA', 'Pb', 'I', 'Br', 'Perovksite depostion method',
#        'Hole transport layer type', 'Conductive electrode layer',
#        'Device structure', 'exposed_time', 'retained_per', 'stability',
#        'cat_efc', 'cat_sta'],
#       dtype='object')

# %%
num_cols = ['Voc (V)',
       'Voc per cell (V)', 'Isc (mA)', 'Jsc (mA/cm^2)', 'FF (%)', 'Pmax (mW)',
       'Vmax (V)', 'Imax (mA)', 'Apeture area (cm^2)', 'MA', 'FA', 'Pb', 'I', 'Br','exposed_time',
       'retained_per']
cat_cols = ['Device size type','Transparent conductive oxide type', 'Electron transport layer type',
       'Sweep direction',
       'Perovksite depostion method', 'Hole transport layer type',
       'Conductive electrode layer', 'Device structure']
cont_tar_cols= [ 'Efficiency (%)','stability']
cat_tar_cols=['cat_efc','cat_sta']

# %%
use_df.head()
# Out:
#    Efficiency (%)  Voc (V)  Voc per cell (V)  Isc (mA)  Jsc (mA/cm^2)  FF (%)  \
# 0           14.14   1.0071            1.0071     4.460      21.339713    65.7
# 1           16.15   1.1085            1.1085     1.840      19.616205    74.2
# 2           12.84   0.8579            0.8579     1.650      22.758621    65.8
# 3           20.11   1.0590            1.0590     2.354      24.649215    77.0
# 4           15.00   1.0900            1.0900    20.960      20.609636    66.8
#
#    Pmax (mW)  Vmax (V)  Imax (mA)  Apeture area (cm^2)  ...    Br  \
# 0       2.96    0.7763      3.810               0.2090  ...  0.00
# 1       1.51    0.9052      1.670               0.0938  ...  0.42
# 2       0.93    0.6540      1.420               0.0725  ...  0.00
# 3       1.92    0.8940      2.148               0.0955  ...  0.15
# 4      15.26    0.8790     17.350               1.0170  ...  0.00
#
#   Perovksite depostion method Hole transport layer type  \
# 0                spin coating              Spiro-OMeTAD
# 1                spin coating                      PTAA
# 2             screen printing                    No HTL
# 3                spin coating                      PTAA
# 4                spin coating                   NiMgLiO
#
#   Conductive electrode layer  Device structure  exposed_time  retained_per  \
# 0                         Au        Mesoscopic         500.0          80.0
# 1                         Au        Mesoscopic         720.0         720.0
# 2      carbon black/graphite        Mesoscopic        1008.0         100.0
# 3                         Au        Mesoscopic         720.0         720.0
# 4                         Ag   Inverted planar        1000.0          97.0
#
#    stability             cat_efc       cat_sta
# 0       40.0       low_efficient      unstable
# 1       64.8  moderate_efficient      unstable
# 2      100.8       low_efficient  low_stabiity
# 3       64.8      high_efficient      unstable
# 4       97.0       low_efficient      unstable
#
# [5 rows x 28 columns]

# %%
from sklearn.preprocessing import LabelEncoder,OneHotEncoder

# %%
import joblib

# %%
use_df["Vmax (V)"].fillna(use_df["Vmax (V)"].mean(),inplace=True)

# %%
use_df["Imax (mA)"].fillna(use_df["Imax (mA)"].mean(),inplace=True)

# %%
mod_df = use_df
for col in cat_cols:
    lbl_enc = LabelEncoder()
    mod_df[col] = lbl_enc.fit_transform(mod_df[col])
    joblib.dump(lbl_enc,f"./serializer_object/label_encoder_categorical/{col}_lbl.pkl")

# %%
mod_df.head()
# Out:
#    Efficiency (%)  Voc (V)  Voc per cell (V)  Isc (mA)  Jsc (mA/cm^2)  FF (%)  \
# 0           14.14   1.0071            1.0071     4.460      21.339713    65.7
# 1           16.15   1.1085            1.1085     1.840      19.616205    74.2
# 2           12.84   0.8579            0.8579     1.650      22.758621    65.8
# 3           20.11   1.0590            1.0590     2.354      24.649215    77.0
# 4           15.00   1.0900            1.0900    20.960      20.609636    66.8
#
#    Pmax (mW)  Vmax (V)  Imax (mA)  Apeture area (cm^2)  ...    Br  \
# 0       2.96    0.7763      3.810               0.2090  ...  0.00
# 1       1.51    0.9052      1.670               0.0938  ...  0.42
# 2       0.93    0.6540      1.420               0.0725  ...  0.00
# 3       1.92    0.8940      2.148               0.0955  ...  0.15
# 4      15.26    0.8790     17.350               1.0170  ...  0.00
#
#    Perovksite depostion method  Hole transport layer type  \
# 0                            6                          5
# 1                            6                          4
# 2                            5                          3
# 3                            6                          4
# 4                            6                          1
#
#    Conductive electrode layer  Device structure  exposed_time  retained_per  \
# 0                           1                 1         500.0          80.0
# 1                           1                 1         720.0         720.0
# 2                           6                 1        1008.0         100.0
# 3                           1                 1         720.0         720.0
# 4                           0                 0        1000.0          97.0
#
#    stability             cat_efc       cat_sta
# 0       40.0       low_efficient      unstable
# 1       64.8  moderate_efficient      unstable
# 2      100.8       low_efficient  low_stabiity
# 3       64.8      high_efficient      unstable
# 4       97.0       low_efficient      unstable
#
# [5 rows x 28 columns]

# %%
for col in cat_tar_cols:
    lbl_enc = LabelEncoder()
    mod_df[col] = lbl_enc.fit_transform(mod_df[col])
    joblib.dump(lbl_enc,f"./serializer_object/label_encoder_categorical/{col}_lbl.pkl")

# %%
mod_df.head()
# Out:
#    Efficiency (%)  Voc (V)  Voc per cell (V)  Isc (mA)  Jsc (mA/cm^2)  FF (%)  \
# 0           14.14   1.0071            1.0071     4.460      21.339713    65.7
# 1           16.15   1.1085            1.1085     1.840      19.616205    74.2
# 2           12.84   0.8579            0.8579     1.650      22.758621    65.8
# 3           20.11   1.0590            1.0590     2.354      24.649215    77.0
# 4           15.00   1.0900            1.0900    20.960      20.609636    66.8
#
#    Pmax (mW)  Vmax (V)  Imax (mA)  Apeture area (cm^2)  ...    Br  \
# 0       2.96    0.7763      3.810               0.2090  ...  0.00
# 1       1.51    0.9052      1.670               0.0938  ...  0.42
# 2       0.93    0.6540      1.420               0.0725  ...  0.00
# 3       1.92    0.8940      2.148               0.0955  ...  0.15
# 4      15.26    0.8790     17.350               1.0170  ...  0.00
#
#    Perovksite depostion method  Hole transport layer type  \
# 0                            6                          5
# 1                            6                          4
# 2                            5                          3
# 3                            6                          4
# 4                            6                          1
#
#    Conductive electrode layer  Device structure  exposed_time  retained_per  \
# 0                           1                 1         500.0          80.0
# 1                           1                 1         720.0         720.0
# 2                           6                 1        1008.0         100.0
# 3                           1                 1         720.0         720.0
# 4                           0                 0        1000.0          97.0
#
#    stability  cat_efc  cat_sta
# 0       40.0        1        2
# 1       64.8        2        2
# 2      100.8        1        0
# 3       64.8        0        2
# 4       97.0        1        2
#
# [5 rows x 28 columns]

# %%
from sklearn.preprocessing import StandardScaler

# %%
sc=StandardScaler()
mod_df=sc.fit_transform(mod_df)

# %%
mod_df=pd.DataFrame(mod_df)

# %%
mod_df.columns = use_df.columns

# %%
mod_df.head()
# Out:
#    Efficiency (%)   Voc (V)  Voc per cell (V)  Isc (mA)  Jsc (mA/cm^2)  \
# 0       -1.267919 -0.323464         -1.276262 -0.337170      -0.523931
# 1       -0.695230 -0.291862          0.132195 -0.400656      -1.269457
# 2       -1.638315 -0.369964         -3.348665 -0.405260       0.089836
# 3        0.433053 -0.307289         -0.555366 -0.388201       0.907637
# 4       -1.022888 -0.297628         -0.124772  0.062648      -0.839735
#
#      FF (%)  Pmax (mW)  Vmax (V)  Imax (mA)  Apeture area (cm^2)  ...  \
# 0 -1.284722  -0.314903 -0.356826  -0.354378            -0.327532  ...
# 1 -0.014569  -0.322863 -0.306780  -0.415367            -0.337084  ...
# 2 -1.269779  -0.326046 -0.404310  -0.422492            -0.338850  ...
# 3  0.403834  -0.320612 -0.311128  -0.401744            -0.336943  ...
# 4 -1.120350  -0.247387 -0.316952   0.031508            -0.260531  ...
#
#          Br  Perovksite depostion method  Hole transport layer type  \
# 0 -0.629548                     0.268293                   0.458000
# 1  0.133282                     0.268293                  -0.340564
# 2 -0.629548                    -0.560976                  -1.139129
# 3 -0.357109                     0.268293                  -0.340564
# 4 -0.629548                     0.268293                  -2.736258
#
#    Conductive electrode layer  Device structure  exposed_time  retained_per  \
# 0                   -0.282809         -0.576297     -0.370628     -0.612762
# 1                   -0.282809         -0.576297     -0.240289      1.731626
# 2                    3.032884         -0.576297     -0.069662     -0.539500
# 3                   -0.282809         -0.576297     -0.240289      1.731626
# 4                   -0.945948         -2.027712     -0.074402     -0.550490
#
#    stability   cat_efc   cat_sta
# 0  -0.400888  0.146095  0.394132
# 1  -0.239710  1.249928  0.394132
# 2  -0.005740  0.146095 -2.955988
# 3  -0.239710 -0.957737  0.394132
# 4  -0.030437  0.146095  0.394132
#
# [5 rows x 28 columns]

# %%
mod_df.to_csv("./main_datasets/completely_scaled_data.csv",index=False)
import numpy as np

# %%
y_reg = np.array(mod_df[cont_tar_cols])
y_cla_efc = np.array(mod_df[cat_tar_cols]['cat_efc'])

# %%
len(cat_cols),len(num_cols)
# Out:
# (8, 16)

# %%
main_x = np.array(mod_df[num_cols+cat_cols])

# %%
from imblearn.over_sampling import SMOTENC

# %%
smote = SMOTENC(categorical_features=cat_cols,sampling_strategy='auto',random_state=123,k_neighbors=3,n_jobs=3)

# %%
lbl_2 = LabelEncoder()
y_cla_efc =pd.DataFrame(y_cla_efc)
y_cla_efc = lbl_2.fit_transform(y_cla_efc)
# Out:
# c:\users\001001\appdata\local\programs\python\python37\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)

# %%
y_cla_efc = np.array(y_cla_efc)
y_cla_efc
# Out:
# array([1, 2, 1, 0, 1, 2, 2, 0, 2, 2, 2, 0, 2, 1, 2, 0, 2, 2, 1, 0, 2, 0,
#        1, 2, 1, 0, 0, 2, 2, 0, 0, 2, 1, 1, 0, 1, 0, 0, 2, 0, 2, 0, 0, 0,
#        1, 0, 0, 2, 2, 2, 0, 0, 0, 0, 0, 0, 2, 0, 0, 2, 2, 0, 0, 2, 0, 0,
#        0, 0], dtype=int64)

# %%
# x,y = smote.fit_resample(main_x,y_cla_efc)

# %%
samp_df = pd.DataFrame(main_x)

# %%
samp_df
# Out:
#           0         1         2         3         4         5         6   \
# 0  -0.323464 -1.276262 -0.337170 -0.523931 -1.284722 -0.314903 -0.356826
# 1  -0.291862  0.132195 -0.400656 -1.269457 -0.014569 -0.322863 -0.306780
# 2  -0.369964 -3.348665 -0.405260  0.089836 -1.269779 -0.326046 -0.404310
# 3  -0.307289 -0.555366 -0.388201  0.907637  0.403834 -0.320612 -0.311128
# 4  -0.297628 -0.124772  0.062648 -0.839735 -1.120350 -0.247387 -0.316952
# ..       ...       ...       ...       ...       ...       ...       ...
# 63 -0.280486  0.639183 -0.416843 -2.210596  0.553264 -0.325410 -0.289386
# 64 -0.275032  0.882260 -0.391894  0.966122  0.587632 -0.319064 -0.277738
# 65 -0.281141  0.610014 -0.406568  0.564739  1.150983 -0.322939 -0.275797
# 66 -0.287655  0.319711 -0.369955  1.136492  0.045202 -0.316874 -0.299092
# 67 -0.294511  0.014129 -0.406350  0.203182  1.079256 -0.323230 -0.285503
#
#           7         8         9   ...        14        15        16        17  \
# 0  -0.354378 -0.327532  1.083360  ... -0.370628 -0.612762  0.157027 -0.811503
# 1  -0.415367 -0.337084  1.083360  ... -0.240289  1.731626  0.157027 -0.811503
# 2  -0.422492 -0.338850  0.885358  ... -0.069662 -0.539500  0.157027 -0.811503
# 3  -0.401744 -0.336943 -0.797655  ... -0.240289  1.731626  0.157027 -0.811503
# 4   0.031508 -0.260531  1.083360  ... -0.074402 -0.550490 -1.622614 -0.811503
# ..       ...       ...       ...  ...       ...       ...       ...       ...
# 63 -0.431583 -0.339290 -0.896656  ... -0.459496 -0.594447  0.157027  1.232282
# 64 -0.404737 -0.337496  0.093352  ... -0.560213 -0.572468  0.157027  1.232282
# 65 -0.419699 -0.339315 -0.738255  ... -0.074402 -0.539500  0.157027  1.232282
# 66 -0.382849 -0.334630 -0.896656  ... -0.665907 -0.568805  0.157027 -0.811503
# 67 -0.420127 -0.339081 -0.896656  ... -0.074402 -0.572468  0.157027 -0.811503
#
#           18        19        20        21        22        23
# 0   1.150045  0.300300  0.268293  0.458000 -0.282809 -0.576297
# 1   1.150045  0.300300  0.268293 -0.340564 -0.282809 -0.576297
# 2   1.150045  0.300300 -0.560976 -1.139129  3.032884 -0.576297
# 3   1.150045 -1.061062  0.268293 -0.340564 -0.282809 -0.576297
# 4  -1.577969  0.980981  0.268293 -2.736258 -0.945948 -2.027712
# ..       ...       ...       ...       ...       ...       ...
# 63 -1.577969  0.980981  0.268293 -1.937693 -0.945948 -2.027712
# 64 -0.668631  0.300300  0.268293  0.458000 -0.282809  0.875118
# 65 -1.577969  1.661662  0.268293 -0.340564  1.706607 -2.027712
# 66 -0.668631  1.661662  0.268293  0.458000 -0.945948  0.875118
# 67 -0.668631  0.980981  0.268293  0.458000 -0.282809  0.875118
#
# [68 rows x 24 columns]

# %%
smote = SMOTENC(categorical_features=[i for i in range(16,24)],sampling_strategy='auto',random_state=123,k_neighbors=3,n_jobs=3)

# %%
x,y = smote.fit_resample(main_x,y_cla_efc)

# %%
len(x),len(y)
# Out:
# (99, 99)

# %%
smoted_data = pd.DataFrame(x)

# %%
smoted_data.columns = mod_df[num_cols+cat_cols].columns

# %%
smoted_data
# Out:
#      Voc (V)  Voc per cell (V)  Isc (mA)  Jsc (mA/cm^2)    FF (%)  Pmax (mW)  \
# 0  -0.323464         -1.276262 -0.337170      -0.523931 -1.284722  -0.314903
# 1  -0.291862          0.132195 -0.400656      -1.269457 -0.014569  -0.322863
# 2  -0.369964         -3.348665 -0.405260       0.089836 -1.269779  -0.326046
# 3  -0.307289         -0.555366 -0.388201       0.907637  0.403834  -0.320612
# 4  -0.297628         -0.124772  0.062648      -0.839735 -1.120350  -0.247387
# ..       ...               ...       ...            ...       ...        ...
# 94 -0.298812         -0.177536 -0.096992       0.366470 -0.132254  -0.268200
# 95 -0.287109          0.344047 -0.218827       0.820862 -0.678832  -0.288675
# 96 -0.311778         -0.755407 -0.160220      -0.843173 -0.097347  -0.327055
# 97 -0.283222          0.517268  0.153217      -0.434784  0.132713  -0.215527
# 98  2.670977          0.039283  1.468819      -0.345911 -1.079527   3.074381
#
#     Vmax (V)  Imax (mA)  Apeture area (cm^2)        MA  ...  exposed_time  \
# 0  -0.356826  -0.354378            -0.327532  1.083360  ...     -0.370628
# 1  -0.306780  -0.415367            -0.337084  1.083360  ...     -0.240289
# 2  -0.404310  -0.422492            -0.338850  0.885358  ...     -0.069662
# 3  -0.311128  -0.401744            -0.336943 -0.797655  ...     -0.240289
# 4  -0.316952   0.031508            -0.260531  1.083360  ...     -0.074402
# ..       ...        ...                  ...       ...  ...           ...
# 94 -0.310541  -0.090827            -0.296378 -0.211632  ...      2.680227
# 95 -0.310957  -0.223116            -0.309760 -0.599654  ...     -0.240289
# 96 -0.155776  -0.203835            -0.297203  1.067269  ...     -0.499420
# 97 -0.294724   0.178749            -0.249721 -0.620222  ...     -0.240289
# 98  2.490729   1.506666             2.824834 -0.225344  ...     -0.280981
#
#     retained_per  Device size type  Transparent conductive oxide type  \
# 0      -0.612762          0.157027                          -0.811503
# 1       1.731626          0.157027                          -0.811503
# 2      -0.539500          0.157027                          -0.811503
# 3       1.731626          0.157027                          -0.811503
# 4      -0.550490         -1.622614                          -0.811503
# ..           ...               ...                                ...
# 94     -0.569844         -1.622614                          -0.811503
# 95      1.731626          0.157027                          -0.811503
# 96     -0.593224         -1.622614                          -0.811503
# 97      1.731626          0.157027                          -0.811503
# 98      0.910006          1.936669                          -0.811503
#
#     Electron transport layer type  Sweep direction  \
# 0                        1.150045         0.300300
# 1                        1.150045         0.300300
# 2                        1.150045         0.300300
# 3                        1.150045        -1.061062
# 4                       -1.577969         0.980981
# ..                            ...              ...
# 94                       1.150045        -0.380381
# 95                       1.150045        -1.061062
# 96                      -1.577969        -0.380381
# 97                       1.150045        -1.061062
# 98                      -0.213962        -1.061062
#
#     Perovksite depostion method  Hole transport layer type  \
# 0                      0.268293                   0.458000
# 1                      0.268293                  -0.340564
# 2                     -0.560976                  -1.139129
# 3                      0.268293                  -0.340564
# 4                      0.268293                  -2.736258
# ..                          ...                        ...
# 94                     0.268293                   0.458000
# 95                     0.268293                   0.458000
# 96                     0.268293                  -2.736258
# 97                     0.268293                   0.458000
# 98                     0.268293                   0.458000
#
#     Conductive electrode layer  Device structure
# 0                    -0.282809         -0.576297
# 1                    -0.282809         -0.576297
# 2                     3.032884         -0.576297
# 3                    -0.282809         -0.576297
# 4                    -0.945948         -2.027712
# ..                         ...               ...
# 94                   -0.282809          0.875118
# 95                   -0.282809         -0.576297
# 96                   -0.945948         -2.027712
# 97                   -0.282809         -0.576297
# 98                   -0.282809          0.875118
#
# [99 rows x 24 columns]

# %%
target_data = pd.DataFrame(y)

# %%
smoted_data["efficiency"] = target_data

# %%
smoted_data.head()
# Out:
#     Voc (V)  Voc per cell (V)  Isc (mA)  Jsc (mA/cm^2)    FF (%)  Pmax (mW)  \
# 0 -0.323464         -1.276262 -0.337170      -0.523931 -1.284722  -0.314903
# 1 -0.291862          0.132195 -0.400656      -1.269457 -0.014569  -0.322863
# 2 -0.369964         -3.348665 -0.405260       0.089836 -1.269779  -0.326046
# 3 -0.307289         -0.555366 -0.388201       0.907637  0.403834  -0.320612
# 4 -0.297628         -0.124772  0.062648      -0.839735 -1.120350  -0.247387
#
#    Vmax (V)  Imax (mA)  Apeture area (cm^2)        MA  ...  retained_per  \
# 0 -0.356826  -0.354378            -0.327532  1.083360  ...     -0.612762
# 1 -0.306780  -0.415367            -0.337084  1.083360  ...      1.731626
# 2 -0.404310  -0.422492            -0.338850  0.885358  ...     -0.539500
# 3 -0.311128  -0.401744            -0.336943 -0.797655  ...      1.731626
# 4 -0.316952   0.031508            -0.260531  1.083360  ...     -0.550490
#
#    Device size type  Transparent conductive oxide type  \
# 0          0.157027                          -0.811503
# 1          0.157027                          -0.811503
# 2          0.157027                          -0.811503
# 3          0.157027                          -0.811503
# 4         -1.622614                          -0.811503
#
#    Electron transport layer type  Sweep direction  \
# 0                       1.150045         0.300300
# 1                       1.150045         0.300300
# 2                       1.150045         0.300300
# 3                       1.150045        -1.061062
# 4                      -1.577969         0.980981
#
#    Perovksite depostion method  Hole transport layer type  \
# 0                     0.268293                   0.458000
# 1                     0.268293                  -0.340564
# 2                    -0.560976                  -1.139129
# 3                     0.268293                  -0.340564
# 4                     0.268293                  -2.736258
#
#    Conductive electrode layer  Device structure  efficiency
# 0                   -0.282809         -0.576297           1
# 1                   -0.282809         -0.576297           2
# 2                    3.032884         -0.576297           1
# 3                   -0.282809         -0.576297           0
# 4                   -0.945948         -2.027712           1
#
# [5 rows x 25 columns]

# %%
smoted_data.to_csv("./main_datasets/smoted_scaled_efficiency_cat_data.csv",index=False)

# %% [markdown]
# # UNWRAPING THE DATA INTO RAW FORM

# %%
y = smoted_data["efficiency"]

# %%
r_y = lbl_2.inverse_transform(y)

# %%
new_smoted_data = pd.DataFrame(r_y)
new_smoted_data.columns=["efficiency"]

# %%
new_smoted_data
# Out:
#     efficiency
# 0     0.146095
# 1     1.249928
# 2     0.146095
# 3    -0.957737
# 4     0.146095
# ..         ...
# 94    1.249928
# 95    1.249928
# 96    1.249928
# 97    1.249928
# 98    1.249928
#
# [99 rows x 1 columns]

# %%
x = smoted_data

# %%
x.drop("efficiency",axis=1,inplace=True)

# %%
sc.inverse_transform(x)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-89-935e22197898> in <module>
# ----> 1 sc.inverse_transform(x)
#
# c:\users\001001\appdata\local\programs\python\python37\lib\site-packages\sklearn\preprocessing\_data.py in inverse_transform(self, X, copy)
#     935                 X = X.copy()
#     936             if self.with_std:
# --> 937                 X *= self.scale_
#     938             if self.with_mean:
#     939                 X += self.mean_
#
# ValueError: operands could not be broadcast together with shapes (99,24) (28,) (99,24)
