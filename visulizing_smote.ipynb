# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# %%
main_df = pd.read_csv("./main_datasets/smoted_data_labeled.csv")

# %%
main_df.head()
# Out:
#    Voc_(V)  Voc_per_cell_(V)  Isc_(mA)  Jsc_(mA/cm^2)  FF_(%)  Pmax_(mW)  \
# 0   1.0071            1.0071     4.460      21.339713    65.7       2.96
# 1   1.1085            1.1085     1.840      19.616205    74.2       1.51
# 2   0.8579            0.8579     1.650      22.758621    65.8       0.93
# 3   1.0590            1.0590     2.354      24.649215    77.0       1.92
# 4   1.0900            1.0900    20.960      20.609636    66.8      15.26
#
#    Vmax_(V)  Imax_(mA)  Apeture_area_(cm^2)    MA  ...  retained_per  \
# 0    0.7763      3.810               0.2090  1.00  ...          80.0
# 1    0.9052      1.670               0.0938  1.00  ...         720.0
# 2    0.6540      1.420               0.0725  0.90  ...         100.0
# 3    0.8940      2.148               0.0955  0.05  ...         720.0
# 4    0.8790     17.350               1.0170  1.00  ...          97.0
#
#        Device_size_type  Transparent_conductive_oxide_type  \
# ...

# %%
main_df.shape
# Out:
# (99, 24)

# %%
non_smote = main_df.loc[:67,:]

# %%
non_smote.head()
# Out:
#    Voc_(V)  Voc_per_cell_(V)  Isc_(mA)  Jsc_(mA/cm^2)  FF_(%)  Pmax_(mW)  \
# 0   1.0071            1.0071     4.460      21.339713    65.7       2.96
# 1   1.1085            1.1085     1.840      19.616205    74.2       1.51
# 2   0.8579            0.8579     1.650      22.758621    65.8       0.93
# 3   1.0590            1.0590     2.354      24.649215    77.0       1.92
# 4   1.0900            1.0900    20.960      20.609636    66.8      15.26
#
#    Vmax_(V)  Imax_(mA)  Apeture_area_(cm^2)    MA  ...  retained_per  \
# 0    0.7763      3.810               0.2090  1.00  ...          80.0
# 1    0.9052      1.670               0.0938  1.00  ...         720.0
# 2    0.6540      1.420               0.0725  0.90  ...         100.0
# 3    0.8940      2.148               0.0955  0.05  ...         720.0
# 4    0.8790     17.350               1.0170  1.00  ...          97.0
#
#        Device_size_type  Transparent_conductive_oxide_type  \
# ...

# %%
smoted = main_df.loc[68:,:]

# %%
smoted.head()
# Out:
#      Voc_(V)  Voc_per_cell_(V)   Isc_(mA)  Jsc_(mA/cm^2)     FF_(%)  \
# 68  0.970952          0.970952   3.779196      21.683485  65.724228
# 69  0.919684          0.919684   1.602673      20.530487  64.307037
# 70  0.921159          0.849401  21.572430      17.832483  43.837649
# 71  1.033694          1.033694   8.604418      18.682033  63.956053
# 72  1.004674          1.004674   3.195095      19.711016  64.240161
#
#     Pmax_(mW)  Vmax_(V)  Imax_(mA)  Apeture_area_(cm^2)        MA  ...  \
# 68   2.468174  0.746669   3.230953             0.175929  0.975772  ...
# 69   0.942907  0.711868   1.333950             0.078997  0.943025  ...
# 70  13.813270  1.712669  18.920399             1.787822  1.000000  ...
# 71   6.161915  0.821421   7.087614             0.425688  1.000000  ...
# 72   2.093627  0.781585   2.688047             0.156411  1.000000  ...
#
#     retained_per      Device_size_type  Transparent_conductive_oxide_type  \
# ...

# %% [markdown]
# # PLOTTING THE GRAPH

# %%
fig = plt.figure(figsize=(10,10))
plt.scatter(x=non_smote["Jsc_(mA/cm^2)"],y=non_smote["FF_(%)"],c="red")
plt.xlabel("Jsc_(mA/cm^2)")
plt.ylabel("FF_(%)")
plt.title("SYNTHESIZED DATA FROM SMOTE")
plt.scatter(x=smoted["Jsc_(mA/cm^2)"],y=smoted["FF_(%)"],c="blue")
plt.show()
fig.savefig("./visualizer/smoted_data.png")

# %%
fig2 = plt.figure(figsize=(10,10))
plt.scatter(x=non_smote["Jsc_(mA/cm^2)"],y=non_smote["FF_(%)"],c="red")
plt.xlabel("Jsc_(mA/cm^2)")
plt.ylabel("FF_(%)")
plt.title("RAW DATA USED")
# plt.scatter(x=smoted["Jsc_(mA/cm^2)"],y=smoted["FF_(%)"],c="blue")
plt.show()
fig2.savefig("./visualizer/non_smoted_data.png")
