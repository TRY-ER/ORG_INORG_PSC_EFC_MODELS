# %%
import joblib
from sklearn.tree import plot_tree
import matplotlib.pyplot as plt
import graphviz

# %%
dc_model = joblib.load("./main_models/DecisionTreeClassifier_folded_models/DecisionTreeClassifier_fold9_tuned.pkl")

# %%
fig = plt.figure(figsize=(20,10),dpi=500)
plot_tree(dc_model,filled=True)
fig.show()
# Out:
# c:\users\001001\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:3: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
# fig.savefig("./model_visualizer/Decision_tree.png")

# %%
from xgboost import plot_tree

# %%
xg_clf = joblib.load("./main_models/XGBClassifier_folded_models/XGBClassifier_fold0_tuned.pkl")

# %%
plot_tree(xg_clf)
# Out:
# Error: <stdin>: syntax error in line 1 near 'bias'
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# c:\users\001001\appdata\local\programs\python\python37\lib\site-packages\graphviz\backend\execute.py in run_check(cmd, input_lines, encoding, capture_output, quiet, **kwargs)
#      94     try:
# ---> 95         proc.check_returncode()
#      96     except subprocess.CalledProcessError as e:
#
# c:\users\001001\appdata\local\programs\python\python37\lib\subprocess.py in check_returncode(self)
#     443             raise CalledProcessError(self.returncode, self.args, self.stdout,
# --> 444                                      self.stderr)
#     445
#
# CalledProcessError: Command '['dot', '-Kdot', '-Tpng']' returned non-zero exit status 1.
#
# During handling of the above exception, another exception occurred:
#
# ...

# %%
for i in range(0,10):
    plot_tree(xg_clf,num_trees=i)
    fig2 = plt.gcf()
    fig2.set_size_inches(100,100)
    fig2.show()
    fig2.savefig(f"./model_visualizer/gradient_boosting_viz/viz_tree_{i}.png")
# Out:
# c:\users\001001\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:5: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   """
