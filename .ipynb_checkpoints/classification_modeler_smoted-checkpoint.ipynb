# %% [markdown]
# # THIS CODE IS COPIED FROM "classification_modeler.ipynb" WITH SLIGHTLY REQUIRED MODIFICATION OF OUTPUT FILES AND CODE FOR CLASSIFICATION MODEL WITH SYNTHETIC DATA

# %%
from sklearn.ensemble import RandomForestClassifier,ExtraTreesClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from xgboost import XGBClassifier

# %%
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split,StratifiedKFold
import joblib
import optuna
import pandas as pd
import numpy as np
import os

# %%
def save_show_model_report(model,x,y,model_name):
    print(f"[++] PRINTING MODEL REPORT FOR MODEL : {model_name}")
    train_x,val_x,train_y,val_y = train_test_split(x,y,test_size=0.1)
    model.fit(train_x,train_y)
    pred_y = model.predict(val_x)
    acc_score = accuracy_score(val_y,pred_y)
    print(f"[++] PRINTING ACCURACY SCORES ....")
    print(f" accuracy_score:{acc_score}")
    print(f"[++] SAVING THE MODEL ")
    return acc_score

# %% [markdown]
# # UNCOMMENT THE MODEL YOU WANT TO RUN IN BELOW FUNCTION

# %%
def objective(trial):
#     rf_clf = RandomForestClassifier(n_estimators=trial.suggest_categorical('rf_est',[100,200,300]),
#                                     criterion=trial.suggest_categorical('rf_crt',["gini","entropy"]),verbose=1)
#     score = save_show_model_report(rf_clf,x,y,"Random_Forest")
#     et_clf = ExtraTreesClassifier(n_estimators=trial.suggest_categorical('et_est',[100,200,300]),
#                                   class_weight=trial.suggest_categorical('et_cl_wt',["balanced", "balanced_subsample"]),verbose=1)
#     score = save_show_model_report(et_clf,x,y,"Extra_Trees")  
#     lr_clf = LogisticRegression(penalty="none",
#                                 C=trial.suggest_categorical('lr_C',[1.0,0.1]),
#                                 solver=trial.suggest_categorical('lr_solver',["newton-cg", "lbfgs", "sag", "saga"])
#                                 ,verbose=1)
#     score = save_show_model_report(lr_clf,x,y,"Logistic_Regression") 
#     Kn_clf = KNeighborsClassifier(n_neighbors=trial.suggest_categorical("k_nei",[3,4,5]),
#                                   weights=trial.suggest_categorical("k_wei",["uniform","distance"]),
#                                   algorithm=trial.suggest_categorical("K_algo",["auto","ball_tree","kd_tree","brute"]),
#                                  p=trial.suggest_categorical("K_p",[1,2]))
#     score = save_show_model_report(Kn_clf,x,y,"K_Neighbors")
    SVC_clf = SVC(kernel=trial.suggest_categorical("SVC_ker",["linear","poly","rbf","sigmoid"]),
                 gamma = trial.suggest_categorical("SVC_gamma",["scale","auto"]),
                 verbose=1)
    score = save_show_model_report(SVC_clf,x,y,"SVC")
#     DT_clf = DecisionTreeClassifier(criterion=trial.suggest_categorical("DT_cri",["gini","entropy"]),
#                                    splitter=trial.suggest_categorical("DT_spl",["best","random"]))
#     score = save_show_model_report(DT_clf,x,y,"Decision_Tree")
#     XGB_clf = XGBClassifier(n_estimators=trial.suggest_categorical("XGB_est",[100,200,300]),
#                            learning_rate = trial.suggest_categorical("XGB_lr",[0.1,0.01,0.001]),
#                            booster= trial.suggest_categorical("XGB_boost",["gbtree","gblinear","dart"]),
#                            tree_method = trial.suggest_categorical("XGB_tree",["exact","approx","hist","gpu_hist"]),
#                            predictor="cpu_predictor")
#     score = save_show_model_report(XGB_clf,x,y,"XGB_Classifier")  
    return score

# %%
main_df = pd.read_csv("./main_datasets/smoted_scaled_efficiency_cat_data.csv")
y = main_df["target"]
main_df.drop("target",axis=1,inplace=True)
x = main_df

# %%
study = optuna.create_study(direction="maximize")
study.optimize(objective,n_trials=100)
print("[++] PRINTING BEST PARAMETERS")
best_p = study.best_params
print(best_p)
# Out:
# [I 2021-12-09 18:19:44,651] A new study created in memory with name: no-name-6b687166-acf3-46d9-8a0f-fab6f22585b4
# [I 2021-12-09 18:19:44,666] Trial 0 finished with value: 0.8 and parameters: {'SVC_ker': 'rbf', 'SVC_gamma': 'auto'}. Best is trial 0 with value: 0.8.
# [I 2021-12-09 18:19:44,676] Trial 1 finished with value: 0.6 and parameters: {'SVC_ker': 'poly', 'SVC_gamma': 'scale'}. Best is trial 0 with value: 0.8.
# [I 2021-12-09 18:19:44,688] Trial 2 finished with value: 0.9 and parameters: {'SVC_ker': 'rbf', 'SVC_gamma': 'auto'}. Best is trial 2 with value: 0.9.
# [I 2021-12-09 18:19:44,697] Trial 3 finished with value: 0.9 and parameters: {'SVC_ker': 'sigmoid', 'SVC_gamma': 'scale'}. Best is trial 2 with value: 0.9.
# [I 2021-12-09 18:19:44,708] Trial 4 finished with value: 1.0 and parameters: {'SVC_ker': 'linear', 'SVC_gamma': 'scale'}. Best is trial 4 with value: 1.0.
# [I 2021-12-09 18:19:44,720] Trial 5 finished with value: 0.7 and parameters: {'SVC_ker': 'poly', 'SVC_gamma': 'scale'}. Best is trial 4 with value: 1.0.
# [I 2021-12-09 18:19:44,730] Trial 6 finished with value: 0.9 and parameters: {'SVC_ker': 'linear', 'SVC_gamma': 'scale'}. Best is trial 4 with value: 1.0.
# [I 2021-12-09 18:19:44,740] Trial 7 finished with value: 0.8 and parameters: {'SVC_ker': 'sigmoid', 'SVC_gamma': 'scale'}. Best is trial 4 with value: 1.0.
# [I 2021-12-09 18:19:44,751] Trial 8 finished with value: 0.9 and parameters: {'SVC_ker': 'rbf', 'SVC_gamma': 'auto'}. Best is trial 4 with value: 1.0.
# [I 2021-12-09 18:19:44,761] Trial 9 finished with value: 0.9 and parameters: {'SVC_ker': 'rbf', 'SVC_gamma': 'auto'}. Best is trial 4 with value: 1.0.
# [I 2021-12-09 18:19:44,773] Trial 10 finished with value: 0.9 and parameters: {'SVC_ker': 'linear', 'SVC_gamma': 'scale'}. Best is trial 4 with value: 1.0.
# [I 2021-12-09 18:19:44,785] Trial 11 finished with value: 0.7 and parameters: {'SVC_ker': 'linear', 'SVC_gamma': 'auto'}. Best is trial 4 with value: 1.0.
# [I 2021-12-09 18:19:44,797] Trial 12 finished with value: 1.0 and parameters: {'SVC_ker': 'linear', 'SVC_gamma': 'auto'}. Best is trial 4 with value: 1.0.
# [I 2021-12-09 18:19:44,808] Trial 13 finished with value: 0.9 and parameters: {'SVC_ker': 'linear', 'SVC_gamma': 'auto'}. Best is trial 4 with value: 1.0.
# [I 2021-12-09 18:19:44,825] Trial 14 finished with value: 1.0 and parameters: {'SVC_ker': 'linear', 'SVC_gamma': 'auto'}. Best is trial 4 with value: 1.0.
# [I 2021-12-09 18:19:44,840] Trial 15 finished with value: 1.0 and parameters: {'SVC_ker': 'linear', 'SVC_gamma': 'scale'}. Best is trial 4 with value: 1.0.
# [++] PRINTING MODEL REPORT FOR MODEL : SVC
# [LibSVM][++] PRINTING ACCURACY SCORES ....
#  accuracy_score:0.8
# [++] SAVING THE MODEL
# [++] PRINTING MODEL REPORT FOR MODEL : SVC
# [LibSVM][++] PRINTING ACCURACY SCORES ....
#  accuracy_score:0.6
# [++] SAVING THE MODEL
# [++] PRINTING MODEL REPORT FOR MODEL : SVC
# [LibSVM][++] PRINTING ACCURACY SCORES ....
#  accuracy_score:0.9
# [++] SAVING THE MODEL
# [++] PRINTING MODEL REPORT FOR MODEL : SVC
# [LibSVM][++] PRINTING ACCURACY SCORES ....
#  accuracy_score:0.9
# [++] SAVING THE MODEL
# [++] PRINTING MODEL REPORT FOR MODEL : SVC
# [LibSVM][++] PRINTING ACCURACY SCORES ....
#  accuracy_score:1.0
# [++] SAVING THE MODEL
# [++] PRINTING MODEL REPORT FOR MODEL : SVC
# [LibSVM][++] PRINTING ACCURACY SCORES ....
#  accuracy_score:0.7
# [++] SAVING THE MODEL
# [++] PRINTING MODEL REPORT FOR MODEL : SVC
# [LibSVM][++] PRINTING ACCURACY SCORES ....
#  accuracy_score:0.9
# [++] SAVING THE MODEL
# [++] PRINTING MODEL REPORT FOR MODEL : SVC
# [LibSVM][++] PRINTING ACCURACY SCORES ....
#  accuracy_score:0.8
# [++] SAVING THE MODEL
# [++] PRINTING MODEL REPORT FOR MODEL : SVC
# [LibSVM][++] PRINTING ACCURACY SCORES ....
#  accuracy_score:0.9
# [++] SAVING THE MODEL
# [++] PRINTING MODEL REPORT FOR MODEL : SVC
# [LibSVM][++] PRINTING ACCURACY SCORES ....
#  accuracy_score:0.9
# [++] SAVING THE MODEL
# [++] PRINTING MODEL REPORT FOR MODEL : SVC
# [LibSVM][++] PRINTING ACCURACY SCORES ....
#  accuracy_score:0.9
# [++] SAVING THE MODEL
# [++] PRINTING MODEL REPORT FOR MODEL : SVC
# [LibSVM][++] PRINTING ACCURACY SCORES ....
#  accuracy_score:0.7
# [++] SAVING THE MODEL
# [++] PRINTING MODEL REPORT FOR MODEL : SVC
# [LibSVM][++] PRINTING ACCURACY SCORES ....
#  accuracy_score:1.0
# [++] SAVING THE MODEL
# [++] PRINTING MODEL REPORT FOR MODEL : SVC
# [LibSVM][++] PRINTING ACCURACY SCORES ....
#  accuracy_score:0.9
# [++] SAVING THE MODEL
# [++] PRINTING MODEL REPORT FOR MODEL : SVC
# [LibSVM][++] PRINTING ACCURACY SCORES ....
#  accuracy_score:1.0
# [++] SAVING THE MODEL
# [++] PRINTING MODEL REPORT FOR MODEL : SVC
# [LibSVM][++] PRINTING ACCURACY SCORES ....
#  accuracy_score:1.0
# [++] SAVING THE MODEL
# [++] PRINTING MODEL REPORT FOR MODEL : SVC
# [I 2021-12-09 18:19:44,854] Trial 16 finished with value: 1.0 and parameters: {'SVC_ker': 'linear', 'SVC_gamma': 'scale'}. Best is trial 4 with value: 1.0.
# [I 2021-12-09 18:19:44,866] Trial 17 finished with value: 0.8 and parameters: {'SVC_ker': 'linear', 'SVC_gamma': 'auto'}. Best is trial 4 with value: 1.0.
# [I 2021-12-09 18:19:44,876] Trial 18 finished with value: 0.4 and parameters: {'SVC_ker': 'poly', 'SVC_gamma': 'scale'}. Best is trial 4 with value: 1.0.
# [I 2021-12-09 18:19:44,889] Trial 19 finished with value: 0.8 and parameters: {'SVC_ker': 'sigmoid', 'SVC_gamma': 'scale'}. Best is trial 4 with value: 1.0.
# [I 2021-12-09 18:19:44,903] Trial 20 finished with value: 1.0 and parameters: {'SVC_ker': 'linear', 'SVC_gamma': 'scale'}. Best is trial 4 with value: 1.0.
# [I 2021-12-09 18:19:44,917] Trial 21 finished with value: 0.8 and parameters: {'SVC_ker': 'linear', 'SVC_gamma': 'scale'}. Best is trial 4 with value: 1.0.
# [I 2021-12-09 18:19:44,929] Trial 22 finished with value: 0.9 and parameters: {'SVC_ker': 'linear', 'SVC_gamma': 'scale'}. Best is trial 4 with value: 1.0.
# [I 2021-12-09 18:19:44,942] Trial 23 finished with value: 0.9 and parameters: {'SVC_ker': 'linear', 'SVC_gamma': 'scale'}. Best is trial 4 with value: 1.0.
# [I 2021-12-09 18:19:44,956] Trial 24 finished with value: 1.0 and parameters: {'SVC_ker': 'linear', 'SVC_gamma': 'auto'}. Best is trial 4 with value: 1.0.
# [I 2021-12-09 18:19:44,968] Trial 25 finished with value: 0.9 and parameters: {'SVC_ker': 'linear', 'SVC_gamma': 'scale'}. Best is trial 4 with value: 1.0.
# [I 2021-12-09 18:19:44,979] Trial 26 finished with value: 0.9 and parameters: {'SVC_ker': 'linear', 'SVC_gamma': 'auto'}. Best is trial 4 with value: 1.0.
# [I 2021-12-09 18:19:44,990] Trial 27 finished with value: 0.8 and parameters: {'SVC_ker': 'sigmoid', 'SVC_gamma': 'scale'}. Best is trial 4 with value: 1.0.
# [I 2021-12-09 18:19:45,003] Trial 28 finished with value: 0.4 and parameters: {'SVC_ker': 'poly', 'SVC_gamma': 'scale'}. Best is trial 4 with value: 1.0.
# [I 2021-12-09 18:19:45,014] Trial 29 finished with value: 0.6 and parameters: {'SVC_ker': 'rbf', 'SVC_gamma': 'auto'}. Best is trial 4 with value: 1.0.
# [I 2021-12-09 18:19:45,025] Trial 30 finished with value: 0.9 and parameters: {'SVC_ker': 'linear', 'SVC_gamma': 'auto'}. Best is trial 4 with value: 1.0.
# [LibSVM][++] PRINTING ACCURACY SCORES ....
#  accuracy_score:1.0
# [++] SAVING THE MODEL
# [++] PRINTING MODEL REPORT FOR MODEL : SVC
# [LibSVM][++] PRINTING ACCURACY SCORES ....
#  accuracy_score:0.8
# [++] SAVING THE MODEL
# [++] PRINTING MODEL REPORT FOR MODEL : SVC
# [LibSVM][++] PRINTING ACCURACY SCORES ....
#  accuracy_score:0.4
# [++] SAVING THE MODEL
# [++] PRINTING MODEL REPORT FOR MODEL : SVC
# [LibSVM][++] PRINTING ACCURACY SCORES ....
#  accuracy_score:0.8
# [++] SAVING THE MODEL
# [++] PRINTING MODEL REPORT FOR MODEL : SVC
# [LibSVM][++] PRINTING ACCURACY SCORES ....
#  accuracy_score:1.0
# [++] SAVING THE MODEL
# [++] PRINTING MODEL REPORT FOR MODEL : SVC
# [LibSVM][++] PRINTING ACCURACY SCORES ....
#  accuracy_score:0.8
# [++] SAVING THE MODEL
# [++] PRINTING MODEL REPORT FOR MODEL : SVC
# [LibSVM][++] PRINTING ACCURACY SCORES ....
#  accuracy_score:0.9
# [++] SAVING THE MODEL
# [++] PRINTING MODEL REPORT FOR MODEL : SVC
# [LibSVM][++] PRINTING ACCURACY SCORES ....
#  accuracy_score:0.9
# [++] SAVING THE MODEL
# [++] PRINTING MODEL REPORT FOR MODEL : SVC
# [LibSVM][++] PRINTING ACCURACY SCORES ....
#  accuracy_score:1.0
# [++] SAVING THE MODEL
# [++] PRINTING MODEL REPORT FOR MODEL : SVC
# [LibSVM][++] PRINTING ACCURACY SCORES ....
#  accuracy_score:0.9
# [++] SAVING THE MODEL
# [++] PRINTING MODEL REPORT FOR MODEL : SVC
# [LibSVM][++] PRINTING ACCURACY SCORES ....
#  accuracy_score:0.9
# [++] SAVING THE MODEL
# [++] PRINTING MODEL REPORT FOR MODEL : SVC
# [LibSVM][++] PRINTING ACCURACY SCORES ....
#  accuracy_score:0.8
# [++] SAVING THE MODEL
# [++] PRINTING MODEL REPORT FOR MODEL : SVC
# [LibSVM][++] PRINTING ACCURACY SCORES ....
#  accuracy_score:0.4
# [++] SAVING THE MODEL
# [++] PRINTING MODEL REPORT FOR MODEL : SVC
# [LibSVM][++] PRINTING ACCURACY SCORES ....
#  accuracy_score:0.6
# [++] SAVING THE MODEL
# [++] PRINTING MODEL REPORT FOR MODEL : SVC
# [LibSVM][++] PRINTING ACCURACY SCORES ....
#  accuracy_score:0.9
# [++] SAVING THE MODEL
# [++] PRINTING MODEL REPORT FOR MODEL : SVC
# [LibSVM]
# [I 2021-12-09 18:19:45,038] Trial 31 finished with value: 0.7 and parameters: {'SVC_ker': 'linear', 'SVC_gamma': 'scale'}. Best is trial 4 with value: 1.0.
# [I 2021-12-09 18:19:45,050] Trial 32 finished with value: 0.8 and parameters: {'SVC_ker': 'linear', 'SVC_gamma': 'auto'}. Best is trial 4 with value: 1.0.
# [I 2021-12-09 18:19:45,063] Trial 33 finished with value: 0.9 and parameters: {'SVC_ker': 'linear', 'SVC_gamma': 'auto'}. Best is trial 4 with value: 1.0.
# [I 2021-12-09 18:19:45,076] Trial 34 finished with value: 0.9 and parameters: {'SVC_ker': 'linear', 'SVC_gamma': 'scale'}. Best is trial 4 with value: 1.0.
# [I 2021-12-09 18:19:45,088] Trial 35 finished with value: 0.5 and parameters: {'SVC_ker': 'poly', 'SVC_gamma': 'scale'}. Best is trial 4 with value: 1.0.
# [I 2021-12-09 18:19:45,101] Trial 36 finished with value: 0.8 and parameters: {'SVC_ker': 'linear', 'SVC_gamma': 'scale'}. Best is trial 4 with value: 1.0.
# [I 2021-12-09 18:19:45,113] Trial 37 finished with value: 1.0 and parameters: {'SVC_ker': 'sigmoid', 'SVC_gamma': 'scale'}. Best is trial 4 with value: 1.0.
# [I 2021-12-09 18:19:45,126] Trial 38 finished with value: 0.9 and parameters: {'SVC_ker': 'sigmoid', 'SVC_gamma': 'scale'}. Best is trial 4 with value: 1.0.
# [I 2021-12-09 18:19:45,139] Trial 39 finished with value: 0.9 and parameters: {'SVC_ker': 'sigmoid', 'SVC_gamma': 'scale'}. Best is trial 4 with value: 1.0.
# [I 2021-12-09 18:19:45,152] Trial 40 finished with value: 1.0 and parameters: {'SVC_ker': 'sigmoid', 'SVC_gamma': 'scale'}. Best is trial 4 with value: 1.0.
# [I 2021-12-09 18:19:45,165] Trial 41 finished with value: 0.8 and parameters: {'SVC_ker': 'sigmoid', 'SVC_gamma': 'scale'}. Best is trial 4 with value: 1.0.
# [I 2021-12-09 18:19:45,177] Trial 42 finished with value: 0.6 and parameters: {'SVC_ker': 'sigmoid', 'SVC_gamma': 'scale'}. Best is trial 4 with value: 1.0.
# [I 2021-12-09 18:19:45,190] Trial 43 finished with value: 0.5 and parameters: {'SVC_ker': 'rbf', 'SVC_gamma': 'scale'}. Best is trial 4 with value: 1.0.
# [I 2021-12-09 18:19:45,203] Trial 44 finished with value: 0.7 and parameters: {'SVC_ker': 'rbf', 'SVC_gamma': 'auto'}. Best is trial 4 with value: 1.0.
# [I 2021-12-09 18:19:45,215] Trial 45 finished with value: 0.7 and parameters: {'SVC_ker': 'sigmoid', 'SVC_gamma': 'scale'}. Best is trial 4 with value: 1.0.
# [++] PRINTING ACCURACY SCORES ....
#  accuracy_score:0.7
# [++] SAVING THE MODEL
# [++] PRINTING MODEL REPORT FOR MODEL : SVC
# [LibSVM][++] PRINTING ACCURACY SCORES ....
#  accuracy_score:0.8
# [++] SAVING THE MODEL
# [++] PRINTING MODEL REPORT FOR MODEL : SVC
# [LibSVM][++] PRINTING ACCURACY SCORES ....
#  accuracy_score:0.9
# [++] SAVING THE MODEL
# [++] PRINTING MODEL REPORT FOR MODEL : SVC
# [LibSVM][++] PRINTING ACCURACY SCORES ....
#  accuracy_score:0.9
# [++] SAVING THE MODEL
# [++] PRINTING MODEL REPORT FOR MODEL : SVC
# [LibSVM][++] PRINTING ACCURACY SCORES ....
#  accuracy_score:0.5
# [++] SAVING THE MODEL
# [++] PRINTING MODEL REPORT FOR MODEL : SVC
# [LibSVM][++] PRINTING ACCURACY SCORES ....
#  accuracy_score:0.8
# [++] SAVING THE MODEL
# [++] PRINTING MODEL REPORT FOR MODEL : SVC
# [LibSVM][++] PRINTING ACCURACY SCORES ....
#  accuracy_score:1.0
# [++] SAVING THE MODEL
# [++] PRINTING MODEL REPORT FOR MODEL : SVC
# [LibSVM][++] PRINTING ACCURACY SCORES ....
#  accuracy_score:0.9
# [++] SAVING THE MODEL
# [++] PRINTING MODEL REPORT FOR MODEL : SVC
# [LibSVM][++] PRINTING ACCURACY SCORES ....
#  accuracy_score:0.9
# [++] SAVING THE MODEL
# [++] PRINTING MODEL REPORT FOR MODEL : SVC
# [LibSVM][++] PRINTING ACCURACY SCORES ....
#  accuracy_score:1.0
# [++] SAVING THE MODEL
# [++] PRINTING MODEL REPORT FOR MODEL : SVC
# [LibSVM][++] PRINTING ACCURACY SCORES ....
#  accuracy_score:0.8
# [++] SAVING THE MODEL
# [++] PRINTING MODEL REPORT FOR MODEL : SVC
# [LibSVM][++] PRINTING ACCURACY SCORES ....
#  accuracy_score:0.6
# [++] SAVING THE MODEL
# [++] PRINTING MODEL REPORT FOR MODEL : SVC
# [LibSVM][++] PRINTING ACCURACY SCORES ....
#  accuracy_score:0.5
# [++] SAVING THE MODEL
# [++] PRINTING MODEL REPORT FOR MODEL : SVC
# [LibSVM][++] PRINTING ACCURACY SCORES ....
#  accuracy_score:0.7
# [++] SAVING THE MODEL
# [++] PRINTING MODEL REPORT FOR MODEL : SVC
# [LibSVM][++] PRINTING ACCURACY SCORES ....
#  accuracy_score:0.7
# [++] SAVING THE MODEL
# [++] PRINTING MODEL REPORT FOR MODEL : SVC
# [LibSVM]
# [I 2021-12-09 18:19:45,226] Trial 46 finished with value: 0.9 and parameters: {'SVC_ker': 'sigmoid', 'SVC_gamma': 'scale'}. Best is trial 4 with value: 1.0.
# [I 2021-12-09 18:19:45,239] Trial 47 finished with value: 1.0 and parameters: {'SVC_ker': 'linear', 'SVC_gamma': 'scale'}. Best is trial 4 with value: 1.0.
# [I 2021-12-09 18:19:45,251] Trial 48 finished with value: 0.9 and parameters: {'SVC_ker': 'linear', 'SVC_gamma': 'auto'}. Best is trial 4 with value: 1.0.
# [I 2021-12-09 18:19:45,264] Trial 49 finished with value: 0.9 and parameters: {'SVC_ker': 'linear', 'SVC_gamma': 'auto'}. Best is trial 4 with value: 1.0.
# [I 2021-12-09 18:19:45,277] Trial 50 finished with value: 1.0 and parameters: {'SVC_ker': 'linear', 'SVC_gamma': 'auto'}. Best is trial 4 with value: 1.0.
# [I 2021-12-09 18:19:45,289] Trial 51 finished with value: 1.0 and parameters: {'SVC_ker': 'linear', 'SVC_gamma': 'auto'}. Best is trial 4 with value: 1.0.
# [I 2021-12-09 18:19:45,303] Trial 52 finished with value: 0.8 and parameters: {'SVC_ker': 'linear', 'SVC_gamma': 'auto'}. Best is trial 4 with value: 1.0.
# [I 2021-12-09 18:19:45,316] Trial 53 finished with value: 1.0 and parameters: {'SVC_ker': 'linear', 'SVC_gamma': 'scale'}. Best is trial 4 with value: 1.0.
# [I 2021-12-09 18:19:45,327] Trial 54 finished with value: 0.7 and parameters: {'SVC_ker': 'linear', 'SVC_gamma': 'scale'}. Best is trial 4 with value: 1.0.
# [I 2021-12-09 18:19:45,341] Trial 55 finished with value: 0.6 and parameters: {'SVC_ker': 'poly', 'SVC_gamma': 'scale'}. Best is trial 4 with value: 1.0.
# [I 2021-12-09 18:19:45,354] Trial 56 finished with value: 1.0 and parameters: {'SVC_ker': 'linear', 'SVC_gamma': 'auto'}. Best is trial 4 with value: 1.0.
# [I 2021-12-09 18:19:45,367] Trial 57 finished with value: 0.8 and parameters: {'SVC_ker': 'linear', 'SVC_gamma': 'auto'}. Best is trial 4 with value: 1.0.
# [I 2021-12-09 18:19:45,379] Trial 58 finished with value: 0.9 and parameters: {'SVC_ker': 'linear', 'SVC_gamma': 'scale'}. Best is trial 4 with value: 1.0.
# [I 2021-12-09 18:19:45,392] Trial 59 finished with value: 0.6 and parameters: {'SVC_ker': 'rbf', 'SVC_gamma': 'scale'}. Best is trial 4 with value: 1.0.
# [I 2021-12-09 18:19:45,407] Trial 60 finished with value: 0.8 and parameters: {'SVC_ker': 'linear', 'SVC_gamma': 'auto'}. Best is trial 4 with value: 1.0.
# [++] PRINTING ACCURACY SCORES ....
#  accuracy_score:0.9
# [++] SAVING THE MODEL
# [++] PRINTING MODEL REPORT FOR MODEL : SVC
# [LibSVM][++] PRINTING ACCURACY SCORES ....
#  accuracy_score:1.0
# [++] SAVING THE MODEL
# [++] PRINTING MODEL REPORT FOR MODEL : SVC
# [LibSVM][++] PRINTING ACCURACY SCORES ....
#  accuracy_score:0.9
# [++] SAVING THE MODEL
# [++] PRINTING MODEL REPORT FOR MODEL : SVC
# [LibSVM][++] PRINTING ACCURACY SCORES ....
#  accuracy_score:0.9
# [++] SAVING THE MODEL
# [++] PRINTING MODEL REPORT FOR MODEL : SVC
# [LibSVM][++] PRINTING ACCURACY SCORES ....
#  accuracy_score:1.0
# [++] SAVING THE MODEL
# [++] PRINTING MODEL REPORT FOR MODEL : SVC
# [LibSVM][++] PRINTING ACCURACY SCORES ....
#  accuracy_score:1.0
# [++] SAVING THE MODEL
# [++] PRINTING MODEL REPORT FOR MODEL : SVC
# [LibSVM][++] PRINTING ACCURACY SCORES ....
#  accuracy_score:0.8
# [++] SAVING THE MODEL
# [++] PRINTING MODEL REPORT FOR MODEL : SVC
# [LibSVM][++] PRINTING ACCURACY SCORES ....
#  accuracy_score:1.0
# [++] SAVING THE MODEL
# [++] PRINTING MODEL REPORT FOR MODEL : SVC
# [LibSVM][++] PRINTING ACCURACY SCORES ....
#  accuracy_score:0.7
# [++] SAVING THE MODEL
# [++] PRINTING MODEL REPORT FOR MODEL : SVC
# [LibSVM][++] PRINTING ACCURACY SCORES ....
#  accuracy_score:0.6
# [++] SAVING THE MODEL
# [++] PRINTING MODEL REPORT FOR MODEL : SVC
# [LibSVM][++] PRINTING ACCURACY SCORES ....
#  accuracy_score:1.0
# [++] SAVING THE MODEL
# [++] PRINTING MODEL REPORT FOR MODEL : SVC
# [LibSVM][++] PRINTING ACCURACY SCORES ....
#  accuracy_score:0.8
# [++] SAVING THE MODEL
# [++] PRINTING MODEL REPORT FOR MODEL : SVC
# [LibSVM][++] PRINTING ACCURACY SCORES ....
#  accuracy_score:0.9
# [++] SAVING THE MODEL
# [++] PRINTING MODEL REPORT FOR MODEL : SVC
# [LibSVM][++] PRINTING ACCURACY SCORES ....
#  accuracy_score:0.6
# [++] SAVING THE MODEL
# [++] PRINTING MODEL REPORT FOR MODEL : SVC
# [LibSVM][++] PRINTING ACCURACY SCORES ....
#  accuracy_score:0.8
# [++] SAVING THE MODEL
# [I 2021-12-09 18:19:45,424] Trial 61 finished with value: 0.8 and parameters: {'SVC_ker': 'linear', 'SVC_gamma': 'auto'}. Best is trial 4 with value: 1.0.
# [I 2021-12-09 18:19:45,439] Trial 62 finished with value: 0.8 and parameters: {'SVC_ker': 'linear', 'SVC_gamma': 'auto'}. Best is trial 4 with value: 1.0.
# [I 2021-12-09 18:19:45,456] Trial 63 finished with value: 0.9 and parameters: {'SVC_ker': 'linear', 'SVC_gamma': 'scale'}. Best is trial 4 with value: 1.0.
# [I 2021-12-09 18:19:45,471] Trial 64 finished with value: 0.8 and parameters: {'SVC_ker': 'linear', 'SVC_gamma': 'auto'}. Best is trial 4 with value: 1.0.
# [I 2021-12-09 18:19:45,486] Trial 65 finished with value: 1.0 and parameters: {'SVC_ker': 'linear', 'SVC_gamma': 'auto'}. Best is trial 4 with value: 1.0.
# [I 2021-12-09 18:19:45,497] Trial 66 finished with value: 0.8 and parameters: {'SVC_ker': 'poly', 'SVC_gamma': 'auto'}. Best is trial 4 with value: 1.0.
# [I 2021-12-09 18:19:45,509] Trial 67 finished with value: 1.0 and parameters: {'SVC_ker': 'linear', 'SVC_gamma': 'scale'}. Best is trial 4 with value: 1.0.
# [I 2021-12-09 18:19:45,522] Trial 68 finished with value: 0.9 and parameters: {'SVC_ker': 'sigmoid', 'SVC_gamma': 'scale'}. Best is trial 4 with value: 1.0.
# [I 2021-12-09 18:19:45,534] Trial 69 finished with value: 0.9 and parameters: {'SVC_ker': 'linear', 'SVC_gamma': 'auto'}. Best is trial 4 with value: 1.0.
# [I 2021-12-09 18:19:45,546] Trial 70 finished with value: 0.9 and parameters: {'SVC_ker': 'linear', 'SVC_gamma': 'scale'}. Best is trial 4 with value: 1.0.
# [I 2021-12-09 18:19:45,558] Trial 71 finished with value: 1.0 and parameters: {'SVC_ker': 'linear', 'SVC_gamma': 'auto'}. Best is trial 4 with value: 1.0.
# [I 2021-12-09 18:19:45,572] Trial 72 finished with value: 0.8 and parameters: {'SVC_ker': 'sigmoid', 'SVC_gamma': 'auto'}. Best is trial 4 with value: 1.0.
# [I 2021-12-09 18:19:45,585] Trial 73 finished with value: 1.0 and parameters: {'SVC_ker': 'linear', 'SVC_gamma': 'auto'}. Best is trial 4 with value: 1.0.
# [++] PRINTING MODEL REPORT FOR MODEL : SVC
# [LibSVM][++] PRINTING ACCURACY SCORES ....
#  accuracy_score:0.8
# [++] SAVING THE MODEL
# [++] PRINTING MODEL REPORT FOR MODEL : SVC
# [LibSVM][++] PRINTING ACCURACY SCORES ....
#  accuracy_score:0.8
# [++] SAVING THE MODEL
# [++] PRINTING MODEL REPORT FOR MODEL : SVC
# [LibSVM][++] PRINTING ACCURACY SCORES ....
#  accuracy_score:0.9
# [++] SAVING THE MODEL
# [++] PRINTING MODEL REPORT FOR MODEL : SVC
# [LibSVM][++] PRINTING ACCURACY SCORES ....
#  accuracy_score:0.8
# [++] SAVING THE MODEL
# [++] PRINTING MODEL REPORT FOR MODEL : SVC
# [LibSVM][++] PRINTING ACCURACY SCORES ....
#  accuracy_score:1.0
# [++] SAVING THE MODEL
# [++] PRINTING MODEL REPORT FOR MODEL : SVC
# [LibSVM][++] PRINTING ACCURACY SCORES ....
#  accuracy_score:0.8
# [++] SAVING THE MODEL
# [++] PRINTING MODEL REPORT FOR MODEL : SVC
# [LibSVM][++] PRINTING ACCURACY SCORES ....
#  accuracy_score:1.0
# [++] SAVING THE MODEL
# [++] PRINTING MODEL REPORT FOR MODEL : SVC
# [LibSVM][++] PRINTING ACCURACY SCORES ....
#  accuracy_score:0.9
# [++] SAVING THE MODEL
# [++] PRINTING MODEL REPORT FOR MODEL : SVC
# [LibSVM][++] PRINTING ACCURACY SCORES ....
#  accuracy_score:0.9
# [++] SAVING THE MODEL
# [++] PRINTING MODEL REPORT FOR MODEL : SVC
# [LibSVM][++] PRINTING ACCURACY SCORES ....
#  accuracy_score:0.9
# [++] SAVING THE MODEL
# [++] PRINTING MODEL REPORT FOR MODEL : SVC
# [LibSVM][++] PRINTING ACCURACY SCORES ....
#  accuracy_score:1.0
# [++] SAVING THE MODEL
# [++] PRINTING MODEL REPORT FOR MODEL : SVC
# [LibSVM][++] PRINTING ACCURACY SCORES ....
#  accuracy_score:0.8
# [++] SAVING THE MODEL
# [++] PRINTING MODEL REPORT FOR MODEL : SVC
# [LibSVM][++] PRINTING ACCURACY SCORES ....
#  accuracy_score:1.0
# [++] SAVING THE MODEL
# [++] PRINTING MODEL REPORT FOR MODEL : SVC
# [LibSVM][++] PRINTING ACCURACY SCORES ....
# [I 2021-12-09 18:19:45,599] Trial 74 finished with value: 0.8 and parameters: {'SVC_ker': 'sigmoid', 'SVC_gamma': 'auto'}. Best is trial 4 with value: 1.0.
# [I 2021-12-09 18:19:45,611] Trial 75 finished with value: 1.0 and parameters: {'SVC_ker': 'sigmoid', 'SVC_gamma': 'auto'}. Best is trial 4 with value: 1.0.
# [I 2021-12-09 18:19:45,624] Trial 76 finished with value: 0.9 and parameters: {'SVC_ker': 'linear', 'SVC_gamma': 'auto'}. Best is trial 4 with value: 1.0.
# [I 2021-12-09 18:19:45,637] Trial 77 finished with value: 1.0 and parameters: {'SVC_ker': 'linear', 'SVC_gamma': 'auto'}. Best is trial 4 with value: 1.0.
# [I 2021-12-09 18:19:45,650] Trial 78 finished with value: 0.6 and parameters: {'SVC_ker': 'sigmoid', 'SVC_gamma': 'scale'}. Best is trial 4 with value: 1.0.
# [I 2021-12-09 18:19:45,662] Trial 79 finished with value: 0.9 and parameters: {'SVC_ker': 'linear', 'SVC_gamma': 'auto'}. Best is trial 4 with value: 1.0.
# [I 2021-12-09 18:19:45,676] Trial 80 finished with value: 0.8 and parameters: {'SVC_ker': 'linear', 'SVC_gamma': 'scale'}. Best is trial 4 with value: 1.0.
# [I 2021-12-09 18:19:45,690] Trial 81 finished with value: 0.9 and parameters: {'SVC_ker': 'linear', 'SVC_gamma': 'auto'}. Best is trial 4 with value: 1.0.
# [I 2021-12-09 18:19:45,703] Trial 82 finished with value: 0.7 and parameters: {'SVC_ker': 'sigmoid', 'SVC_gamma': 'scale'}. Best is trial 4 with value: 1.0.
# [I 2021-12-09 18:19:45,717] Trial 83 finished with value: 0.8 and parameters: {'SVC_ker': 'sigmoid', 'SVC_gamma': 'auto'}. Best is trial 4 with value: 1.0.
# [I 2021-12-09 18:19:45,731] Trial 84 finished with value: 0.8 and parameters: {'SVC_ker': 'linear', 'SVC_gamma': 'scale'}. Best is trial 4 with value: 1.0.
# [I 2021-12-09 18:19:45,744] Trial 85 finished with value: 0.8 and parameters: {'SVC_ker': 'rbf', 'SVC_gamma': 'scale'}. Best is trial 4 with value: 1.0.
# [I 2021-12-09 18:19:45,759] Trial 86 finished with value: 0.4 and parameters: {'SVC_ker': 'poly', 'SVC_gamma': 'auto'}. Best is trial 4 with value: 1.0.
# [I 2021-12-09 18:19:45,772] Trial 87 finished with value: 0.9 and parameters: {'SVC_ker': 'linear', 'SVC_gamma': 'scale'}. Best is trial 4 with value: 1.0.
#  accuracy_score:0.8
# [++] SAVING THE MODEL
# [++] PRINTING MODEL REPORT FOR MODEL : SVC
# [LibSVM][++] PRINTING ACCURACY SCORES ....
#  accuracy_score:1.0
# [++] SAVING THE MODEL
# [++] PRINTING MODEL REPORT FOR MODEL : SVC
# [LibSVM][++] PRINTING ACCURACY SCORES ....
#  accuracy_score:0.9
# [++] SAVING THE MODEL
# [++] PRINTING MODEL REPORT FOR MODEL : SVC
# [LibSVM][++] PRINTING ACCURACY SCORES ....
#  accuracy_score:1.0
# [++] SAVING THE MODEL
# [++] PRINTING MODEL REPORT FOR MODEL : SVC
# [LibSVM][++] PRINTING ACCURACY SCORES ....
#  accuracy_score:0.6
# [++] SAVING THE MODEL
# [++] PRINTING MODEL REPORT FOR MODEL : SVC
# [LibSVM][++] PRINTING ACCURACY SCORES ....
#  accuracy_score:0.9
# [++] SAVING THE MODEL
# [++] PRINTING MODEL REPORT FOR MODEL : SVC
# [LibSVM][++] PRINTING ACCURACY SCORES ....
#  accuracy_score:0.8
# [++] SAVING THE MODEL
# [++] PRINTING MODEL REPORT FOR MODEL : SVC
# [LibSVM][++] PRINTING ACCURACY SCORES ....
#  accuracy_score:0.9
# [++] SAVING THE MODEL
# [++] PRINTING MODEL REPORT FOR MODEL : SVC
# [LibSVM][++] PRINTING ACCURACY SCORES ....
#  accuracy_score:0.7
# [++] SAVING THE MODEL
# [++] PRINTING MODEL REPORT FOR MODEL : SVC
# [LibSVM][++] PRINTING ACCURACY SCORES ....
#  accuracy_score:0.8
# [++] SAVING THE MODEL
# [++] PRINTING MODEL REPORT FOR MODEL : SVC
# [LibSVM][++] PRINTING ACCURACY SCORES ....
#  accuracy_score:0.8
# [++] SAVING THE MODEL
# [++] PRINTING MODEL REPORT FOR MODEL : SVC
# [LibSVM][++] PRINTING ACCURACY SCORES ....
#  accuracy_score:0.8
# [++] SAVING THE MODEL
# [++] PRINTING MODEL REPORT FOR MODEL : SVC
# [LibSVM][++] PRINTING ACCURACY SCORES ....
#  accuracy_score:0.4
# [++] SAVING THE MODEL
# [++] PRINTING MODEL REPORT FOR MODEL : SVC
# [LibSVM][++] PRINTING ACCURACY SCORES ....
#  accuracy_score:0.9
# [++] SAVING THE MODEL
# [++] PRINTING MODEL REPORT FOR MODEL : SVC
# [LibSVM][++] PRINTING ACCURACY SCORES ....
# [I 2021-12-09 18:19:45,784] Trial 88 finished with value: 0.7 and parameters: {'SVC_ker': 'sigmoid', 'SVC_gamma': 'auto'}. Best is trial 4 with value: 1.0.
# [I 2021-12-09 18:19:45,797] Trial 89 finished with value: 1.0 and parameters: {'SVC_ker': 'sigmoid', 'SVC_gamma': 'scale'}. Best is trial 4 with value: 1.0.
# [I 2021-12-09 18:19:45,808] Trial 90 finished with value: 1.0 and parameters: {'SVC_ker': 'sigmoid', 'SVC_gamma': 'scale'}. Best is trial 4 with value: 1.0.
# [I 2021-12-09 18:19:45,823] Trial 91 finished with value: 0.8 and parameters: {'SVC_ker': 'sigmoid', 'SVC_gamma': 'scale'}. Best is trial 4 with value: 1.0.
# [I 2021-12-09 18:19:45,838] Trial 92 finished with value: 0.9 and parameters: {'SVC_ker': 'linear', 'SVC_gamma': 'auto'}. Best is trial 4 with value: 1.0.
# [I 2021-12-09 18:19:45,851] Trial 93 finished with value: 1.0 and parameters: {'SVC_ker': 'linear', 'SVC_gamma': 'scale'}. Best is trial 4 with value: 1.0.
# [I 2021-12-09 18:19:45,862] Trial 94 finished with value: 0.9 and parameters: {'SVC_ker': 'linear', 'SVC_gamma': 'auto'}. Best is trial 4 with value: 1.0.
# [I 2021-12-09 18:19:45,874] Trial 95 finished with value: 0.9 and parameters: {'SVC_ker': 'linear', 'SVC_gamma': 'auto'}. Best is trial 4 with value: 1.0.
# [I 2021-12-09 18:19:45,887] Trial 96 finished with value: 0.9 and parameters: {'SVC_ker': 'linear', 'SVC_gamma': 'scale'}. Best is trial 4 with value: 1.0.
# [I 2021-12-09 18:19:45,900] Trial 97 finished with value: 0.9 and parameters: {'SVC_ker': 'linear', 'SVC_gamma': 'auto'}. Best is trial 4 with value: 1.0.
# [I 2021-12-09 18:19:45,911] Trial 98 finished with value: 0.7 and parameters: {'SVC_ker': 'linear', 'SVC_gamma': 'auto'}. Best is trial 4 with value: 1.0.
# [I 2021-12-09 18:19:45,924] Trial 99 finished with value: 0.9 and parameters: {'SVC_ker': 'sigmoid', 'SVC_gamma': 'scale'}. Best is trial 4 with value: 1.0.
#  accuracy_score:0.7
# [++] SAVING THE MODEL
# [++] PRINTING MODEL REPORT FOR MODEL : SVC
# [LibSVM][++] PRINTING ACCURACY SCORES ....
#  accuracy_score:1.0
# [++] SAVING THE MODEL
# [++] PRINTING MODEL REPORT FOR MODEL : SVC
# [LibSVM][++] PRINTING ACCURACY SCORES ....
#  accuracy_score:1.0
# [++] SAVING THE MODEL
# [++] PRINTING MODEL REPORT FOR MODEL : SVC
# [LibSVM][++] PRINTING ACCURACY SCORES ....
#  accuracy_score:0.8
# [++] SAVING THE MODEL
# [++] PRINTING MODEL REPORT FOR MODEL : SVC
# [LibSVM][++] PRINTING ACCURACY SCORES ....
#  accuracy_score:0.9
# [++] SAVING THE MODEL
# [++] PRINTING MODEL REPORT FOR MODEL : SVC
# [LibSVM][++] PRINTING ACCURACY SCORES ....
#  accuracy_score:1.0
# [++] SAVING THE MODEL
# [++] PRINTING MODEL REPORT FOR MODEL : SVC
# [LibSVM][++] PRINTING ACCURACY SCORES ....
#  accuracy_score:0.9
# [++] SAVING THE MODEL
# [++] PRINTING MODEL REPORT FOR MODEL : SVC
# [LibSVM][++] PRINTING ACCURACY SCORES ....
#  accuracy_score:0.9
# [++] SAVING THE MODEL
# [++] PRINTING MODEL REPORT FOR MODEL : SVC
# [LibSVM][++] PRINTING ACCURACY SCORES ....
#  accuracy_score:0.9
# [++] SAVING THE MODEL
# [++] PRINTING MODEL REPORT FOR MODEL : SVC
# [LibSVM][++] PRINTING ACCURACY SCORES ....
#  accuracy_score:0.9
# [++] SAVING THE MODEL
# [++] PRINTING MODEL REPORT FOR MODEL : SVC
# [LibSVM][++] PRINTING ACCURACY SCORES ....
#  accuracy_score:0.7
# [++] SAVING THE MODEL
# [++] PRINTING MODEL REPORT FOR MODEL : SVC
# [LibSVM][++] PRINTING ACCURACY SCORES ....
#  accuracy_score:0.9
# [++] SAVING THE MODEL
# [++] PRINTING BEST PARAMETERS
# {'SVC_ker': 'linear', 'SVC_gamma': 'scale'}

# %% [markdown]
# # MENTION MODEL NAME BELOW

# %%
modelName = "SVC" #EDIT MODEL NAME HERE

# %%
skf = StratifiedKFold(n_splits=10,shuffle=True,random_state=123)
acc_list = []
for num,(train_idx,test_idx) in enumerate(skf.split(x,y)):
    main_clf_model= SVC(kernel="linear",gamma="scale")      #change the model here acc to the objective function 
    x_train,x_test = x.loc[train_idx],x.loc[test_idx]
    y_train,y_test = y.loc[train_idx],y.loc[test_idx]
    main_clf_model.fit(x_train,y_train)
    score = main_clf_model.score(x_test,y_test)
    acc_list.append(score)
    print(score)
    print(f"[++] FOLD {num} DEPOSITED")
    try:
        joblib.dump(main_clf_model,f"./smoted_models/{modelName}_folded_models/{modelName}_fold{num}_tuned.pkl")
        print(f"[++] FOLD {num} model is deposited")
    except:
        os.mkdir(f"./smoted_models/{modelName}_folded_models")
        print(f"[++] FILE SYSTEM CREATED ")
        joblib.dump(main_clf_model,f"./smoted_models/{modelName}_folded_models/{modelName}_fold{num}_tuned.pkl")
        print(f"[++] FOLD {num} model is deposited")
# Out:
# 0.9
# [++] FOLD 0 DEPOSITED
# [++] FOLD 0 model is deposited
# 0.8
# [++] FOLD 1 DEPOSITED
# [++] FOLD 1 model is deposited
# 0.9
# [++] FOLD 2 DEPOSITED
# [++] FOLD 2 model is deposited
# 0.7
# [++] FOLD 3 DEPOSITED
# [++] FOLD 3 model is deposited
# 0.9
# [++] FOLD 4 DEPOSITED
# [++] FOLD 4 model is deposited
# 0.8
# [++] FOLD 5 DEPOSITED
# [++] FOLD 5 model is deposited
# 1.0
# [++] FOLD 6 DEPOSITED
# [++] FOLD 6 model is deposited
# 0.9
# [++] FOLD 7 DEPOSITED
# [++] FOLD 7 model is deposited
# 1.0
# [++] FOLD 8 DEPOSITED
# [++] FOLD 8 model is deposited
# 1.0
# [++] FOLD 9 DEPOSITED
# [++] FOLD 9 model is deposited

# %%
def mean(li):
    tot = 0
    for i in li:
        tot+=i
    m = tot/len(li)
    return m

# %%
log = f'LOG FOR :{(modelName)} \n'
log += "BEST PARAMETERS :: "
log += str(best_p)
log += "\n"
log += "\n MODEL RESULTS\n"
log += f"AVERAGE ACCURACY : {mean(acc_list)}\n"
log += f"MAX ACCURACY : {max(acc_list)}\n"
log += f"MIN ACCURACY : {min(acc_list)}"

# %%
print(log)
# Out:
# LOG FOR :SVC
# BEST PARAMETERS :: {'SVC_ker': 'linear', 'SVC_gamma': 'scale'}
#
#  MODEL RESULTS
# AVERAGE ACCURACY : 0.89
# MAX ACCURACY : 1.0
# MIN ACCURACY : 0.7

# %%
with open(f"./smoted_models/{modelName}_folded_models/{modelName}_log.txt","w+") as file:
    file.write(log)
    file.close()
